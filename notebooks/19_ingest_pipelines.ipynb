# %% [markdown]
# ## Documentation
#
# To read more about the ingest pipeline, checkout the docs [here](https://www.elastic.co/guide/en/elasticsearch/reference/current/ingest.html).
#
# ![ingest_pipeline_docs](../images/ingest_pipeline_docs.png)

# %% [markdown]
# ## Connect to ElasticSearch

# %%
from pprint import pprint
from elasticsearch import Elasticsearch

es = Elasticsearch('http://localhost:9200')
client_info = es.info()
print('Connected to Elasticsearch!')
pprint(client_info.body)
# Out:
# Connected to Elasticsearch!
# {'cluster_name': 'docker-cluster',
#  'cluster_uuid': '5fozJPhCTPWMMruL8IGYpw',
#  'name': '58939253e330',
#  'tagline': 'You Know, for Search',
#  'version': {'build_date': '2024-08-05T10:05:34.233336849Z',
#              'build_flavor': 'default',
#              'build_hash': '1a77947f34deddb41af25e6f0ddb8e830159c179',
#              'build_snapshot': False,
#              'build_type': 'docker',
#              'lucene_version': '9.11.1',
#              'minimum_index_compatibility_version': '7.0.0',
#              'minimum_wire_compatibility_version': '7.17.0',
#              'number': '8.15.0'}}

# %% [markdown]
# ## Create the pipeline

# %%
from pprint import pprint

response = es.ingest.put_pipeline(
    id='lowercase_pipeline',
    description='This pipeline transforms the text to lowercase',
    processors=[
        {
            "lowercase": {
                "field": "text"
            }
        }
    ]
)
pprint(response.body)
# Out:
# {'acknowledged': True}

# %% [markdown]
# ## Get the pipeline

# %%
response = es.ingest.get_pipeline(id='lowercase_pipeline')
pprint(response.body)
# Out:
# {'lowercase_pipeline': {'description': 'This pipeline transforms the text to '
#                                        'lowercase',
#                         'processors': [{'lowercase': {'field': 'text'}}]}}

# %% [markdown]
# ## Delete a pipeline

# %%
response = es.ingest.delete_pipeline(id='lowercase_pipeline')
pprint(response.body)
# Out:
# {'acknowledged': True}

# %% [markdown]
# ## Simulate a pipeline

# %% [markdown]
# The simulate method allows you to give the pipeline fake data just to test if it is working or not. This is usually done before applying the pipeline to your real index and data.

# %%
response = es.ingest.put_pipeline(
    id='lowercase_pipeline',
    description='This pipeline transforms the text to lowercase',
    processors=[
        {
            "lowercase": {
                "field": "text"
            }
        }
    ]
)
pprint(response.body)
# Out:
# {'acknowledged': True}

# %% [markdown]
# Inside the docs list, we are providing some test data. After executing the cell, nothing will be indexed. You will just get back how the documents will look like after the transformation.

# %%
response = es.ingest.simulate(
    id='lowercase_pipeline',
    docs=[
        {
            "_index": "my_index",
            "_id": "1",
            "_source": {
                "text": "HELLO WORLD"
            }
        }
    ]
)
pprint(response.body)
# Out:
# {'docs': [{'doc': {'_id': '1',
#                    '_index': 'my_index',
#                    '_ingest': {'timestamp': '2025-10-27T09:20:40.86012105Z'},
#                    '_source': {'text': 'hello world'},
#                    '_version': '-3'}}]}

# %% [markdown]
# ## Use the pipeline

# %% [markdown]
# Let's read the data and make the text uppercased to see if the `lowercase_pipeline` will be executed before indexing the documents.

# %%
import json

dummy_data = json.load(open("../data/dummy_data.json"))
for i, document in enumerate(dummy_data):
    uppercased_text = document['text'].upper()
    document['text'] = uppercased_text
    dummy_data[i] = document

dummy_data
# Out:
# [{'title': 'Sample Title 1',
#   'text': 'THIS IS THE FIRST SAMPLE DOCUMENT TEXT.',
#   'created_on': '2024-09-22'},
#  {'title': 'Sample Title 2',
#   'text': 'HERE IS ANOTHER EXAMPLE OF A DOCUMENT.',
#   'created_on': '2024-09-24'},
#  {'title': 'Sample Title 3',
#   'text': 'THE CONTENT OF THE THIRD DOCUMENT GOES HERE.',
#   'created_on': '2024-09-24'}]

# %%
es.indices.delete(index='my_index', ignore_unavailable=True)
es.indices.create(index='my_index')
# Out:
# ObjectApiResponse({'acknowledged': True, 'shards_acknowledged': True, 'index': 'my_index'})

# %% [markdown]
# Now, we pass the `lowercase_pipeline` to the bulk method. It will perform the transformations before indexing the documents.

# %%
operations = []
for document in dummy_data:
    operations.append({'index': {'_index': 'my_index'}})
    operations.append(document)

response = es.bulk(operations=operations, pipeline='lowercase_pipeline')
pprint(response.body)
# Out:
# {'errors': False,
#  'ingest_took': 401,
#  'items': [{'index': {'_id': 'XUMaJZoBDFuwVDFof3Wv',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 0,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'XkMaJZoBDFuwVDFof3Wv',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 1,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'X0MaJZoBDFuwVDFof3Wv',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 2,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}}],
#  'took': 113175419}

# %% [markdown]
# After indexing the documents, we can see that the `text` field for all documents has been lowercased. This indicates the pipeline did run with no issues.

# %%
response = es.search(index='my_index')
hits = response.body['hits']['hits']

for hit in hits:
    print(hit['_source'])
# Out:
# {'title': 'Sample Title 1', 'created_on': '2024-09-22', 'text': 'this is the first sample document text.'}
# {'title': 'Sample Title 2', 'created_on': '2024-09-24', 'text': 'here is another example of a document.'}
# {'title': 'Sample Title 3', 'created_on': '2024-09-24', 'text': 'the content of the third document goes here.'}

# %% [markdown]
# ## Pipeline failure

# %% [markdown]
# ### 1. Not handling the failure

# %% [markdown]
# In this scenario, we don’t handle failures with `ignore_failure` or `on_failure`. Instead, the pipeline will raise an exception, halting execution of any further processes, and the document will not be indexed.

# %%
response = es.ingest.put_pipeline(
    id='pipeline_1',
    description='Pipeline with multiple transformations',
    processors=[
        {
            "lowercase": {
                "field": "text",
            }
        },
        {
            "set": {
                "field": "text",
                "value": "CHANGED BY PIPELINE",
            }
        },
    ]
)
pprint(response.body)
# Out:
# {'acknowledged': True}

# %%
document = {
    'title': 'Sample Title 4',
    'created_on': '2024-09-25',
}

response = es.index(
    index='my_index',
    pipeline='pipeline_1',
    body=document
)
pprint(response.body)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[12], line 6
#       1 document = {
#       2     'title': 'Sample Title 4',
#       3     'created_on': '2024-09-25',
#       4 }
# ----> 6 response = es.index(
#       7     index='my_index',
#       8     pipeline='pipeline_1',
#       9     body=document
#      10 )
#      11 pprint(response.body)
#
# File ~/Desktop/Project Repo/Elastic-Search/ElasticSearch_Python_Tutorial/venv/lib/python3.13/site-packages/elasticsearch/_sync/client/utils.py:446, in _rewrite_parameters.<locals>.wrapper.<locals>.wrapped(*args, **kwargs)
#     443         except KeyError:
#     444             pass
# --> 446 return api(*args, **kwargs)
#
# File ~/Desktop/Project Repo/Elastic-Search/ElasticSearch_Python_Tutorial/venv/lib/python3.13/site-packages/elasticsearch/_sync/client/__init__.py:2428, in Elasticsearch.index(self, index, document, body, id, error_trace, filter_path, human, if_primary_term, if_seq_no, op_type, pipeline, pretty, refresh, require_alias, routing, timeout, version, version_type, wait_for_active_shards)
#    2426 __body = document if document is not None else body
#    2427 __headers = {"accept": "application/json", "content-type": "application/json"}
# -> 2428 return self.perform_request(  # type: ignore[return-value]
#    2429     __method,
#    2430     __path,
#    2431     params=__query,
#    2432     headers=__headers,
#    2433     body=__body,
#    2434     endpoint_id="index",
#    2435     path_parts=__path_parts,
#    2436 )
#
# File ~/Desktop/Project Repo/Elastic-Search/ElasticSearch_Python_Tutorial/venv/lib/python3.13/site-packages/elasticsearch/_sync/client/_base.py:271, in BaseClient.perform_request(self, method, path, params, headers, body, endpoint_id, path_parts)
#     255 def perform_request(
#     256     self,
#     257     method: str,
#    (...)    264     path_parts: Optional[Mapping[str, Any]] = None,
#     265 ) -> ApiResponse[Any]:
#     266     with self._otel.span(
#     267         method,
#     268         endpoint_id=endpoint_id,
#     269         path_parts=path_parts or {},
#     270     ) as otel_span:
# --> 271         response = self._perform_request(
#     272             method,
#     273             path,
#     274             params=params,
#     275             headers=headers,
#     276             body=body,
#     277             otel_span=otel_span,
#     278         )
#     279         otel_span.set_elastic_cloud_metadata(response.meta.headers)
#     280         return response
#
# File ~/Desktop/Project Repo/Elastic-Search/ElasticSearch_Python_Tutorial/venv/lib/python3.13/site-packages/elasticsearch/_sync/client/_base.py:352, in BaseClient._perform_request(self, method, path, params, headers, body, otel_span)
#     349         except (ValueError, KeyError, TypeError):
#     350             pass
# --> 352     raise HTTP_EXCEPTIONS.get(meta.status, ApiError)(
#     353         message=message, meta=meta, body=resp_body
#     354     )
#     356 # 'X-Elastic-Product: Elasticsearch' should be on every 2XX response.
#     357 if not self._verified_elasticsearch:
#     358     # If the header is set we mark the server as verified.
#
# BadRequestError: BadRequestError(400, 'illegal_argument_exception', 'field [text] not present as part of path [text]')

# %% [markdown]
# ### 2. Handling the failure

# %% [markdown]
# To handle the failures, we use `ignore_failure` or define an `on_failure` block. With `ignore_failure`, the pipeline will skip over the failed step and continue executing subsequent processes without interrupting the flow, allowing other documents to be indexed.
#
# Alternatively, with `on_failure`, we can specify custom error-handling steps, such as logging the error, retrying, or sending notifications, ensuring the pipeline proceeds even if one step encounters an issue.

# %%
response = es.ingest.put_pipeline(
    id='pipeline_2',
    description='Pipeline with multiple transformations, handling and ignoring failures',
    processors=[
        {
            "lowercase": {
                "field": "text",
                "on_failure": [
                    {
                        "set": {
                            "field": "text",
                            "value": "FAILED TO LOWERCASING",
                            "ignore_failure": True,
                        }
                    }
                ]
            }
        },
        {
            "set": {
                "field": "new_field",
                "value": "ADDED BY PIPELINE",
                "ignore_failure": True,
            }
        },
    ]
)
pprint(response.body)
# Out:
# {'acknowledged': True}

# %%
document = {
    'title': 'Sample Title 4',
    'created_on': '2024-09-25',
}

response = es.index(
    index='my_index',
    pipeline='pipeline_2',
    body=document
)
pprint(response.body)
# Out:
# {'_id': 'YEMeJZoBDFuwVDFon3Vn',
#  '_index': 'my_index',
#  '_primary_term': 1,
#  '_seq_no': 3,
#  '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#  '_version': 1,
#  'result': 'created'}

# %%
response = es.search(index='my_index')
hits = response.body['hits']['hits']
for hit in hits:
    pprint(hit['_source'])
# Out:
# {'created_on': '2024-09-22',
#  'text': 'this is the first sample document text.',
#  'title': 'Sample Title 1'}
# {'created_on': '2024-09-24',
#  'text': 'here is another example of a document.',
#  'title': 'Sample Title 2'}
# {'created_on': '2024-09-24',
#  'text': 'the content of the third document goes here.',
#  'title': 'Sample Title 3'}
# {'created_on': '2024-09-25',
#  'new_field': 'ADDED BY PIPELINE',
#  'text': 'FAILED TO LOWERCASE',
#  'title': 'Sample Title 4'}
